# %%
# A Script to Pre-process WikiArt dataset
# This script helps to discard the "bad" images
# which cannot be well used during the training.

from __future__ import print_function

import sys
import warnings
import traceback
import numpy as np

from os import remove
from os import listdir
from os.path import join
from datetime import datetime
from matplotlib.pyplot import imread
# from scipy.misc import imresize
# from scipy.misc import imread, imresize

# %%
DATA_SET_PATH = '../../_input/style/'


def list_images(directory):
    images = []
    for file in listdir(directory):
        name = file.lower()
        if name.endswith('.png'):
            images.append(join(directory, file))
        elif name.endswith('.jpg'):
            images.append(join(directory, file))
        elif name.endswith('.jpeg'):
            images.append(join(directory, file))
    return images


def main(dir_path):
    warnings.filterwarnings('error')
    warnings.filterwarnings('ignore', category=DeprecationWarning)

    paths = list_images(dir_path)

    print('\nOrigin files number: %d\n' % len(paths))

    num_delete = 0

    for path in paths:
        is_continue = False

        try:
#             image = imread(path, mode='RGB')
            image = imread(path)
        except Warning as warn:
            is_continue = True
            num_delete += 1
            remove(path)

            print('>>> Warning happens! Removes image <%s>' % path)
            print('Warning detail:\n%s\n' % str(warn))
        except Exception as exc:
            is_continue = True
            num_delete += 1
            remove(path)

            print('>>> Exception happens! Removes image <%s>' % path)
            print('Exception detail:\n%s\n' % str(exc))

        if is_continue:
            continue

        if len(image.shape) != 3 or image.shape[2] != 3:
            num_delete += 1
            remove(path)

            print('>>> Found an image with shape: %s; Now removes it: <%s>\n' % (str(image.shape), path))
        else:
            height, width, _ = image.shape

            if height < width:
                new_height = 512
                new_width  = int(width * new_height / height)
            else:
                new_width  = 512
                new_height = int(height * new_width / width)

            try:
                image = imresize(image, [new_height, new_width], interp='nearest')
            except:
                num_delete += 1
                remove(path)
                
                print('>>> Fails to resize an image! Now removes it: <%s>\n' % path)
                traceback.print_exception(*sys.exc_info())

    print('\n>>>>> delete %d files! Current number of files: %d\n' % (num_delete, len(paths) - num_delete))


if __name__ == '__main__':
    t0 = datetime.now()

    main(DATA_SET_PATH)

    print('Elapsed time: %s\n' % (datetime.now() - t0))
# Out:
# Origin files number: 79433
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/39628.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/11751.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/62697.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/88965.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/97260.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/79877.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/67738.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/58069.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/25237.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/48407.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18719.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/17978.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/84206.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/20827.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/84669.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/25.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/57268.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/9386.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/54756.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/40570.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/63442.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/92784.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/78411.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/8883.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/58358.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/69659.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/39678.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/20272.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/1227.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/83665.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/55277.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/76946.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/15905.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/70473.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/65273.jpg>
#
# >>> Exception happens! Removes image <../../_input/style/75180.jpg>
# Exception detail:
# local variable 'photoshop' referenced before assignment
#
# >>> Exception happens! Removes image <../../_input/style/93669.jpg>
# Exception detail:
# local variable 'photoshop' referenced before assignment
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18700.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/75456.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/25772.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/70509.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/61994.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/97527.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/100717.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/16132.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/65351.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/3345.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/89286.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/94213.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/36950.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/94232.jpg>
#
# >>> Found an image with shape: (894, 658); Now removes it: <../../_input/style/79592.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/11961.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/103032.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/32035.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/32392.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/29600.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/92860.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/89044.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/32356.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/37153.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/85196.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/31440.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/65334.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/58530.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/91584.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/16019.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/14564.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/43653.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/34093.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/85686.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/17371.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/39050.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/54478.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/53450.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18883.jpg>
#
# >>> Found an image with shape: (600, 593, 4); Now removes it: <../../_input/style/22580.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/43138.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/100715.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/98718.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/4742.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/84320.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/5186.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/56299.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/21861.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/14499.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/92074.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/85022.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/102081.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/81619.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/19516.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/10816.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/52535.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/7744.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/10135.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/86283.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/67399.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/97929.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/11675.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/35833.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/57063.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/100868.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/16164.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/34904.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/83927.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/50732.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/71045.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/54463.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/84743.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/53780.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/37168.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/40958.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/30107.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/97083.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/91923.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/101952.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/62488.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/77728.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/78460.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/55037.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/44005.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/29895.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/97803.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/23440.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/10183.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/39949.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/80286.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/8917.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/8012.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/7830.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/83627.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/61914.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/15185.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/36951.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/38476.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/14639.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/44555.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/16819.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/91931.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/64044.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/73271.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/94934.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/39551.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/57311.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/89790.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/82103.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/7138.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/51411.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/59653.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/63294.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/103085.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/45023.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/36677.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18105.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/59378.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/52148.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/43240.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/85029.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/49921.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/52614.jpg>
#
# >>> Found an image with shape: (1073, 850); Now removes it: <../../_input/style/56838.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/42162.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/8818.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/21509.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/89710.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/71195.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/90088.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/96837.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/71909.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/79719.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/22676.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/35485.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/79199.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
# ...
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/67560.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/67960.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/82663.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/47417.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/15610.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/42431.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/38903.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/80492.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/33985.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/5745.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/91693.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/52416.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/79433.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/70223.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/12726.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/70552.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/1147.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/79643.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/17568.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/65888.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/70944.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/57300.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/87250.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/11118.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/70804.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/26943.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/33368.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/49850.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/48211.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/96490.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/100593.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/53064.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/69994.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/49660.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/21981.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/1518.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/74394.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/27347.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/11503.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/68880.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/13671.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/54990.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/40534.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/60383.jpg>
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/74075.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/43011.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18430.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/24378.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/24912.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/49556.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/90563.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/35812.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/96829.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/18789.jpg>
#
# >>> Exception happens! Removes image <../../_input/style/2242.jpg>
# Exception detail:
# local variable 'photoshop' referenced before assignment
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# Traceback (most recent call last):
#   File "<ipython-input-9-8cd550985711>", line 67, in main
#     image = imresize(image, [new_height, new_width], interp='nearest')
# NameError: name 'imresize' is not defined
# >>> Fails to resize an image! Now removes it: <../../_input/style/61082.jpg>
#
# >>> Fails to resize an image! Now removes it: <../../_input/style/70740.jpg>

# %%
import cv2 as cv
# im = cv.imread(image.jpg)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-e4d6dffb2ccc> in <module>
# ----> 1 import cv2 as cv
#       2 # im = cv.imread(image.jpg)
#
# ImportError: No module named 'cv2'
